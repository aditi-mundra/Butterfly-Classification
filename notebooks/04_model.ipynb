# %%
import sys
from pathlib import Path

project_root = Path.cwd().parent

if str(project_root) not in sys.path:
    sys.path.append(str(project_root))

# %%
from src.model import build_xception_model

# %%
model = build_xception_model(
    input_shape=(224,224,3),
    num_classes=10
)
# Out:
# ...
# 83683744/83683744 ━━━━━━━━━━━━━━━━━━━━ 20s 0us/step

# %%
model.summary()

# %%
print(f"Total layers: {len(model.layers)}")
# Out:
# Total layers: 137

# %%
print(f"Trainable params: {sum([layer.count_params() for layer in model.layers if layer.trainable]):,}")
# Out:
# Trainable params: 263,562

# %%
print(f"Non-trainable params: {sum([layer.count_params() for layer in model.layers if not layer.trainable]):,}")
# Out:
# Non-trainable params: 20,861,480
