# %%
import sys
from pathlib import Path

project_root = Path().resolve().parent
sys.path.append(str(project_root))

# %%
from src.data_loader import load_leeds_dataset

images, labels = load_leeds_dataset(
    "../data/raw/leedsbutterfly/images"
)

print(images.shape)
print(labels.shape)
# Out:
# (832, 224, 224, 3)
# (832,)

# %%
print(labels[:10])
print(len(set(labels)))
# Out:
# ['001' '001' '001' '001' '001' '001' '001' '001' '001' '001']
# 10

# %%
from src.eda import (
    plot_class_distribution,
    show_sample_images,
    save_current_figure
)

# %%
fig = plot_class_distribution(labels)

fig.savefig(
    "../outputs/figures/class_distribution.png",
    dpi=300,
    bbox_inches="tight"
)

fig.show()
# Out:
# C:\Users\Aditi Mundra\AppData\Local\Temp\ipykernel_13932\3906936358.py:9: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
show_sample_images(images, labels)
save_current_figure(
    "../outputs/figures/sample_images.png"
)
